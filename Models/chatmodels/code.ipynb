# %%
pip install langchain_openai

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

Chat = ChatOpenAI(
    model="gpt-4o",
    temperature=0.5,
    max_tokens=4096,
)

result = chat.invoke("what is the capital of France?")  
print(result)

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv

Chat = ChatAnthropic(
    model="claude-2",
    temperature=0.5,
    max_tokens=4096,
)

result = chat.invoke("what is the capital of France?")
print(result.content)

# %%
pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.8-py3-none-any.whl.metadata (7.0 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.68 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-google-genai) (0.3.72)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-google-genai) (2.11.7)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.4)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2025.7.14)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.3.1)
# Downloading langchain_google_genai-2.1.8-py3-none-any.whl (47 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 762.0 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 882.6 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 986.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 986.8 kB/s  0:00:01
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.5 MB 1.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.0/4.5 MB 1.8 MB/s eta 0:00:02
#    -------------- ------------------------- 1.6/4.5 MB 2.0 MB/s eta 0:00:02
#    ------------------ --------------------- 2.1/4.5 MB 2.0 MB/s eta 0:00:02
#    --------------------- ------------------ 2.4/4.5 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.1/4.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.1/4.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 3.4/4.5 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.9/4.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  4.5/4.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 1.9 MB/s  0:00:02
# Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: filetype, pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-ai-generativelanguage, langchain-google-genai
#
#    -- -------------------------------------  1/14 [pyasn1]
#    -- -------------------------------------  1/14 [pyasn1]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    ----- ----------------------------------  2/14 [protobuf]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------- -------------------------------  3/14 [grpcio]
#    -------------- -------------------------  5/14 [rsa]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    ----------------- ----------------------  6/14 [pyasn1-modules]
#    -------------------- -------------------  7/14 [proto-plus]
#    -------------------- -------------------  7/14 [proto-plus]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ---------------------- -----------------  8/14 [googleapis-common-protos]
#    ------------------------- --------------  9/14 [grpcio-status]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ---------------------------- ----------- 10/14 [google-auth]
#    ------------------------------- -------- 11/14 [google-api-core]
#    ------------------------------- -------- 11/14 [google-api-core]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    --------------------------------- ----- 12/14 [google-ai-generativelanguage]
#    ------------------------------------- -- 13/14 [langchain-google-genai]
#    ---------------------------------------- 14/14 [langchain-google-genai]
#
# Successfully installed cachetools-5.5.2 filetype-1.2.0 google-ai-generativelanguage-0.6.18 google-api-core-2.25.1 google-auth-2.40.3 googleapis-common-protos-1.70.0 grpcio-1.74.0 grpcio-status-1.74.0 langchain-google-genai-2.1.8 proto-plus-1.26.1 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()

chat = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0.5,
    max_tokens=4096,
)

result = chat.invoke("what is Jane Street?")
print(result.content)
# Out:
# Jane Street is a quantitative trading firm based in New York City.  They're known for:
#
# * **Proprietary Trading:**  They primarily trade their own capital, rather than managing money for clients. This means they profit directly from their trading strategies.
#
# * **High-Frequency Trading (HFT):** While they don't exclusively rely on HFT, it's a significant part of their operations.  They use sophisticated algorithms and technology to execute trades at extremely high speeds.
#
# * **Strong Engineering and Mathematical Focus:** Jane Street is renowned for its highly skilled employees, many with advanced degrees in mathematics, computer science, and related fields.  They place a strong emphasis on rigorous engineering practices and developing their own internal tools and systems.
#
# * **Culture and Compensation:** They're known for a strong, collaborative culture and competitive compensation packages, attracting top talent from around the world.
#
# * **Emphasis on Functional Programming:**  They are particularly well-known for their internal use and advocacy of functional programming languages like OCaml.
#
# In short, Jane Street is a highly successful, technology-driven trading firm that uses advanced mathematical and computational techniques to profit from financial markets.  They are often considered a leader in the quantitative finance industry.

# %%
# !pip install huggingface-hub
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: huggingface-hub in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (0.34.3)
# Requirement already satisfied: filelock in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: requests in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub) (4.14.1)
# Requirement already satisfied: colorama in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from tqdm>=4.42.1->huggingface-hub) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub) (2025.7.14)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-huggingface) (0.3.72)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: huggingface-hub>=0.33.4 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-huggingface) (0.34.3)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.0.0)
# Requirement already satisfied: filelock in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2025.7.0)
# Requirement already satisfied: requests in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (2.5.0)
# Requirement already satisfied: colorama in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepu\anaconda3\envs\langchain\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.5 MB/s  0:00:00
# Installing collected packages: tokenizers, langchain-huggingface
#
#    ---------------------------------------- 2/2 [langchain-huggingface]
#
# Successfully installed langchain-huggingface-0.3.1 tokenizers-0.21.4

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
)

model = ChatHuggingFace(
    llm=llm)

result = model.invoke("what is the capital of France?")

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/featherless-ai/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[39], line 14
#       6 llm = HuggingFaceEndpoint(
#       7     repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#       8     task="text-generation",
#       9 )
#      11 model = ChatHuggingFace(
#      12     llm=llm)
# ---> 14 model.invoke("what is the capital of France?")
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)    390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:980, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     971 @override
#     972 def generate_prompt(
#     973     self,
#    (...)    977     **kwargs: Any,
#     978 ) -> LLMResult:
#     979     prompt_messages = [p.to_messages() for p in prompts]
# --> 980     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:799, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     796 for i, m in enumerate(input_messages):
#     797     try:
#     798         results.append(
# --> 799             self._generate_with_cache(
#     800                 m,
#     801                 stop=stop,
#     802                 run_manager=run_managers[i] if run_managers else None,
#     803                 **kwargs,
#     804             )
#     805         )
#     806     except BaseException as e:
#     807         if run_managers:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:1045, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1043     result = generate_from_stream(iter(chunks))
#    1044 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1045     result = self._generate(
#    1046         messages, stop=stop, run_manager=run_manager, **kwargs
#    1047     )
#    1048 else:
#    1049     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_huggingface\chat_models\huggingface.py:577, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     570     message_dicts, params = self._create_message_dicts(messages, stop)
#     571     params = {
#     572         "stop": stop,
#     573         **params,
#     574         **({"stream": stream} if stream is not None else {}),
#     575         **kwargs,
#     576     }
# --> 577     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     578     return self._create_chat_result(answer)
#     579 llm_input = self._to_chat_prompt(messages)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_client.py:922, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     894 parameters = {
#     895     "model": payload_model,
#     896     "frequency_penalty": frequency_penalty,
#    (...)    913     **(extra_body or {}),
#     914 }
#     915 request_parameters = provider_helper.prepare_request(
#     916     inputs=messages,
#     917     parameters=parameters,
#    (...)    920     api_key=self.token,
#     921 )
# --> 922 data = self._inner_post(request_parameters, stream=stream)
#     924 if stream:
#     925     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_client.py:278, in InferenceClient._inner_post(self, request_parameters, stream)
#     275         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     277 try:
# --> 278     hf_raise_for_status(response)
#     279     return response.iter_lines() if stream else response.content
#     280 except HTTPError as error:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/featherless-ai/v1/chat/completions

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from dotenv import load_dotenv

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
)

model = ChatHuggingFace(
    llm=llm)

result = model.invoke("what is the capital of France?")

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/featherless-ai/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[40], line 14
#       6 llm = HuggingFaceEndpoint(
#       7     repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#       8     task="text-generation",
#       9 )
#      11 model = ChatHuggingFace(
#      12     llm=llm)
# ---> 14 result = model.invoke("what is the capital of France?")
#      16 print(result.content)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)    390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:980, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     971 @override
#     972 def generate_prompt(
#     973     self,
#    (...)    977     **kwargs: Any,
#     978 ) -> LLMResult:
#     979     prompt_messages = [p.to_messages() for p in prompts]
# --> 980     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:799, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     796 for i, m in enumerate(input_messages):
#     797     try:
#     798         results.append(
# --> 799             self._generate_with_cache(
#     800                 m,
#     801                 stop=stop,
#     802                 run_manager=run_managers[i] if run_managers else None,
#     803                 **kwargs,
#     804             )
#     805         )
#     806     except BaseException as e:
#     807         if run_managers:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\chat_models.py:1045, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1043     result = generate_from_stream(iter(chunks))
#    1044 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1045     result = self._generate(
#    1046         messages, stop=stop, run_manager=run_manager, **kwargs
#    1047     )
#    1048 else:
#    1049     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_huggingface\chat_models\huggingface.py:577, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     570     message_dicts, params = self._create_message_dicts(messages, stop)
#     571     params = {
#     572         "stop": stop,
#     573         **params,
#     574         **({"stream": stream} if stream is not None else {}),
#     575         **kwargs,
#     576     }
# --> 577     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     578     return self._create_chat_result(answer)
#     579 llm_input = self._to_chat_prompt(messages)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_client.py:922, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     894 parameters = {
#     895     "model": payload_model,
#     896     "frequency_penalty": frequency_penalty,
#    (...)    913     **(extra_body or {}),
#     914 }
#     915 request_parameters = provider_helper.prepare_request(
#     916     inputs=messages,
#     917     parameters=parameters,
#    (...)    920     api_key=self.token,
#     921 )
# --> 922 data = self._inner_post(request_parameters, stream=stream)
#     924 if stream:
#     925     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_client.py:278, in InferenceClient._inner_post(self, request_parameters, stream)
#     275         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     277 try:
# --> 278     hf_raise_for_status(response)
#     279     return response.iter_lines() if stream else response.content
#     280 except HTTPError as error:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/featherless-ai/v1/chat/completions

# %%
from langchain_huggingface import HuggingFaceEndpoint
from dotenv import load_dotenv

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    temperature=0.5,
    max_new_tokens=256
)

response = llm.invoke("What is the capital of France?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 13
#       4 load_dotenv()
#       6 llm = HuggingFaceEndpoint(
#       7     repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#       8     task="text-generation",
#       9     temperature=0.5,
#      10     max_new_tokens=256
#      11 )
# ---> 13 response = llm.invoke("What is the capital of France?")
#      14 print(response)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
#     394             metadata=config.get("metadata"),
#     395             run_name=config.get("run_name"),
#     396             run_id=config.pop("run_id", None),
#     397             **kwargs,
#     398         )
#     399         .generations[0][0]
#     400         .text
#     401     )
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\llms.py:766, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     757 @override
#     758 def generate_prompt(
#     759     self,
#    (...)    763     **kwargs: Any,
#     764 ) -> LLMResult:
#     765     prompt_strings = [p.to_string() for p in prompts]
# --> 766     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\llms.py:971, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     956 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     957     run_managers = [
#     958         callback_manager.on_llm_start(
#     959             self._serialized,
#    (...)    969         )
#     970     ]
# --> 971     return self._generate_helper(
#     972         prompts,
#     973         stop,
#     974         run_managers,
#     975         new_arg_supported=bool(new_arg_supported),
#     976         **kwargs,
#     977     )
#     978 if len(missing_prompts) > 0:
#     979     run_managers = [
#     980         callback_managers[idx].on_llm_start(
#     981             self._serialized,
#    (...)    988         for idx in missing_prompt_idxs
#     989     ]
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     781 def _generate_helper(
#     782     self,
#     783     prompts: list[str],
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     try:
#     791         output = (
# --> 792             self._generate(
#     793                 prompts,
#     794                 stop=stop,
#     795                 # TODO: support multiple run managers
#     796                 run_manager=run_managers[0] if run_managers else None,
#     797                 **kwargs,
#     798             )
#     799             if new_arg_supported
#     800             else self._generate(prompts, stop=stop)
#     801         )
#     802     except BaseException as e:
#     803         for run_manager in run_managers:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_core\language_models\llms.py:1544, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1541 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1542 for prompt in prompts:
#    1543     text = (
# -> 1544         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1545         if new_arg_supported
#    1546         else self._call(prompt, stop=stop, **kwargs)
#    1547     )
#    1548     generations.append([Generation(text=text)])
#    1549 return LLMResult(generations=generations)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\langchain_huggingface\llms\huggingface_endpoint.py:318, in HuggingFaceEndpoint._call(self, prompt, stop, run_manager, **kwargs)
#     315         completion += chunk.text
#     316     return completion
# --> 318 response_text = self.client.text_generation(
#     319     prompt=prompt,
#     320     model=self.model,
#     321     **invocation_params,
#     322 )
#     324 # Maybe the generation has stopped at one of the stop sequences:
#     325 # then we remove this stop sequence from the end of the generated text
#     326 for stop_seq in invocation_params["stop"]:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_client.py:2296, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2294 model_id = model or self.model
#    2295 provider_helper = get_provider_helper(self.provider, task="text-generation", model=model_id)
# -> 2296 request_parameters = provider_helper.prepare_request(
#    2297     inputs=prompt,
#    2298     parameters=parameters,
#    2299     extra_payload={"stream": stream},
#    2300     headers=self.headers,
#    2301     model=model_id,
#    2302     api_key=self.token,
#    2303 )
#    2305 # Handle errors separately for more precise error messages
#    2306 try:
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_providers\_common.py:90, in TaskProviderHelper.prepare_request(self, inputs, parameters, headers, model, api_key, extra_payload)
#      87 api_key = self._prepare_api_key(api_key)
#      89 # mapped model from HF model ID
# ---> 90 provider_mapping_info = self._prepare_mapping_info(model)
#      92 # default HF headers + user headers (to customize in subclasses)
#      93 headers = self._prepare_headers(headers, api_key)
#
# File c:\Users\Deepu\anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\inference\_providers\_common.py:159, in TaskProviderHelper._prepare_mapping_info(self, model)
#     156     raise ValueError(f"Model {model} is not supported by provider {self.provider}.")
#     158 if provider_mapping.task != self.task:
# --> 159     raise ValueError(
#     160         f"Model {model} is not supported for task {self.task} and provider {self.provider}. "
#     161         f"Supported task: {provider_mapping.task}."
#     162     )
#     164 if provider_mapping.status == "staging":
#     165     logger.warning(
#     166         f"Model {model} is in staging mode for provider {self.provider}. Meant for test purposes only."
#     167     )
#
# ValueError: Model TinyLlama/TinyLlama-1.1B-Chat-v1.0 is not supported for task text-generation and provider featherless-ai. Supported task: conversational.
